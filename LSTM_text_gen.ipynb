# %%
import pandas as pd
import numpy as np
from IPython.display import HTML

from __future__ import print_function
import keras
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM, RNN, SimpleRNNCell, SimpleRNN
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.
# tf.estimator package not installed.
# tf.estimator package not installed.

# %%
companies = pd.read_csv('names.txt', header=None)
companies.head()
# Out:
#         0
# 0  Aaberg
# 1   Aalst
# 2    Aara
# 3   Aaren
# 4  Aarika

# %%
names = companies[0].values
text = '\n'.join(names)

chars = sorted(list(set(text)))
print('total chars: {}'.format(len(chars)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 56

# %%
maxlen = 10
step = 3

sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
print('First 10 sequences and next chars:')
for i in range(10):
    print('[{}]:[{}]'.format(sentences[i], next_chars[i]))
# Out:
# Number of sequences: 52450
# First 10 sequences and next chars:
# [Aaberg
# Aal]:[s]
# [erg
# Aalst
# ]:[A]
# [
# Aalst
# Aar]:[a]
# [lst
# Aara
# A]:[a]
# [
# Aara
# Aare]:[n]
# [ra
# Aaren
# A]:[a]
# [Aaren
# Aari]:[k]
# [en
# Aarika
# ]:[A]
# [Aarika
# Aar]:[o]
# [ika
# Aaron
# ]:[A]

# %%
print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('Size of X: {:.2f} MB'.format(X.nbytes/1024/1024))
print('Size of y: {:.2f} MB'.format(y.nbytes/1024/1024))
# Out:
# Vectorization...
# Size of X: 28.00 MB
# Size of y: 2.00 MB

# %%
# ### Initialization
# 
# Now we are ready to create a recurrent model.  Keras contains three types of recurrent layers:
# 
#  * `SimpleRNN`, a fully-connected RNN where the output is fed back to input.
#  * `LSTM`, the Long-Short Term Memory unit layer.
#  * `GRU`, the Gated Recurrent Unit layer.
# 
# See https://keras.io/layers/recurrent/ for more information.

# Number of hidden units to use:
nb_units = 64

model = Sequential()

# Recurrent layers supported: SimpleRNN, LSTM, GRU:
model.add(LSTM(nb_units, input_shape=(maxlen, len(chars))))

# To stack multiple RNN layers, all RNN layers except the last one need
# to have "return_sequences=True".  An example of using two RNN layers:
#model.add(SimpleRNN(16,
#                    input_shape=(maxlen, len(chars)),
#                    return_sequences=True))
#model.add(SimpleRNN(32))

model.add(Dense(units=len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer)

print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 64)                30976
# _________________________________________________________________
# dense_1 (Dense)              (None, 56)                3640
# _________________________________________________________________
# activation_1 (Activation)    (None, 56)                0
# =================================================================
# Total params: 34,616
# Trainable params: 34,616
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
generated_file = open("generated.txt","w")
class SampleResult(keras.callbacks.Callback):

    def on_epoch_end(self, epoch, logs={}):

        start_index = random.randint(0, len(text) - maxlen - 1)

        for diversity in [0.2, 0.5, 1.0, 1.2]:
            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print()
            print('----- Generating with diversity',
                  diversity, 'seed: "' + sentence + '"')
            sys.stdout.write(generated)
            
         

            for i in range(100):
                x = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x[0, t, char_indices[char]] = 1.

                preds = self.model.predict(x, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                generated += next_char
                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
                generated_file.write(generated)
                sys.stdout.flush()
        print('\n\n')
sample_callback = SampleResult()

# %%
history = model.fit(X, y, 
                        epochs=10, 
                        batch_size=512,
                        verbose=2,
                       callbacks=[sample_callback])

generated_file.close()
# Out:
# Epoch 1/10
#  - 11s - loss: 0.5997
#
# ----- Generating with diversity 0.2 seed: "helle
# Mech"
# helle
# Mechlee
# Mechell
# Meceley
# Mecely
# Meckin
# Meciav
# Mecie
# Meceley
# Mecela
# Mecer
# Mecela
# Mecer
# Mecele
# Meckerty
# Mec
# ----- Generating with diversity 0.5 seed: "helle
# Mech"
# helle
# Mechlie
# Meceline
# Mecrelli
# Mecrellia
# Merlich
# Merlick
# Merlick
# Merlick
# Merlige
# Merlia
# Merlinda
# Merlieda
# Mer
# ----- Generating with diversity 1.0 seed: "helle
# Mech"
# helle
# Mechlee
# Mecera
# Mecky
# Meciar
# Mecye
# Mederi
# Meelar
# Meeon
# Meffa
# Mehalen
# Mehgam
# Miggi
# Miggi
# Migging
# Milg
# Mime
# ----- Generating with diversity 1.2 seed: "helle
# Mech"
# helle
# Mechliah
# Meckie
# Meciena
# Meciento
# Mecieusza
# Mecut
# Ceed
# Cuel
# Rucans
# Ruchy
# Ruciberg
# Ruckin
# Ruccerfor
# Ruckin
#
#
# Epoch 2/10
#  - 11s - loss: 0.5961
#
# ----- Generating with diversity 0.2 seed: "ta
# Aretha
# "
# ta
# Aretha
# Aretis
# Arei
# Aseiti
# Ashire
# Ashiris
# Ashrer
# Ashren
# Ashres
# Ashrey
# Ashre
# Asharis
# Asharssa
# Ashussa
# Ashuste
# ----- Generating with diversity 0.5 seed: "ta
# Aretha
# "
# ta
# Aretha
# Arethia
# Arethoine
# Aretl
# Arged
# Arhes
# Aree
# Areehis
# Areend
# Aresten
# Arsem
# Arse
# Psrist
# Psrast
# Psssen
# Pssi
# ----- Generating with diversity 1.0 seed: "ta
# Aretha
# "
# ta
# Aretha
# Are
# Vragla
# Vrailie
# Varilia
# Varim
# Varrin
# Varrine
# Vari
# Varreanid
# Barkon
# Barksh
# Barkle
# Barktert
# Barchyl
# ----- Generating with diversity 1.2 seed: "ta
# Aretha
# "
# ta
# Aretha
# Arethy
# Arewkis
# Arwen
# Ary
# Ary
# Ary
# Arybalda
# AstaAlito
# Anisie
# Annill
# Anny
# Arno
# Ororstine
# Orsty
# Orswil
# O
#
#
# Epoch 3/10
#  - 13s - loss: 0.5916
#
# ----- Generating with diversity 0.2 seed: "
# Rodney
# Ro"
#
# Rodney
# Rodone
# Redine
# Redmine
# Redind
# Reiming
# Reimine
# Reiming
# Reimin
# Reiniah
# Reinfeid
# Reiwell
# Reixa
# Reya
# Reyach
# ----- Generating with diversity 0.5 seed: "
# Rodney
# Ro"
#
# Rodney
# Rodos
# Rodmsed
# Romdding
# Ramdina
# Ramdina
# Ramdina
# Ramdin
# Rammin
# Ramman
# Ramm
# Rame
# Ramey
# Ramiel
# Ramie
# Eamia
# ----- Generating with diversity 1.0 seed: "
# Rodney
# Ro"
#
# Rodney
# Rodos
# Rodweld
# Rowefie
# Rowell
# Rowlef
# Rowerlee
# Centera
# Cenelle
# Cenelle
# Cenerle
# Cenestia
# Yeonsice
# Yigblig
# ----- Generating with diversity 1.2 seed: "
# Rodney
# Ro"
#
# Rodney
# Rodowedn
# Rodoe
# Roddicia
# Roddie
# Roddye
# Roddy
# Redera
# Redina
# Redlie
# Rediy
# Reefy
# Rekes
# Reke
# Reka
# Rek
# Rombe
#
#
# Epoch 4/10
#  - 12s - loss: 0.5950
#
# ----- Generating with diversity 0.2 seed: "p
# Torr
# Tor"
# p
# Torr
# Torvor
# Torvy
# Torvor
# Torvy
# Torvor
# Torvy
# Torvor
# Torvy
# Torvor
# Torvy
# Torvor
# Torvy
# Torvor
# Torvy
# Torvor
# Torvy
# ----- Generating with diversity 0.5 seed: "p
# Torr
# Tor"
# p
# Torr
# Torvor
# Torvy
# Torvor
# Torvy
# Torvor
# Tormy
# Tormo
# Tormie
# Tornier
# Tornis
# Tornin
# Torrins
# Torrmouson
# Nrusky
# Nur
# ----- Generating with diversity 1.0 seed: "p
# Torr
# Tor"
# p
# Torr
# Torvor
# Tormi
# Tornie
# Torringe
# Torrove
# Torrm
# Torgann
# Torges
# Toridge
# Torige
# Toriguro
# Torrner
# Torrlee
# Frorm
# ----- Generating with diversity 1.2 seed: "p
# Torr
# Tor"
# p
# Torr
# Torvor
# Tormic
# Torn
# Tornannoul
# Fena
# Fentia
# Fenvey
# Feni
# Feinne
# Feinvett
# Fein
# Hein
# Heinch
# Hienc
# Heinardin
#
#
#
# Epoch 5/10
#  - 14s - loss: 0.5892
#
# ----- Generating with diversity 0.2 seed: "lisandra
# M"
# lisandra
# Miasney
# Masina
# Masila
# Masill
# Masilo
# Masillia
# Majoran
# Macgh
# Mandi
# Mandia
# Mandi
# Mandia
# Mandi
# Mandia
# Man
# ----- Generating with diversity 0.5 seed: "lisandra
# M"
# lisandra
# Miasney
# Giatlin
# Gianni
# Gianne
# Gianner
# Gianna
# Gianalee
# Gianna
# Gianes
# Gianali
# Gianna
# Gianes
# Gianale
# Gia
# ----- Generating with diversity 1.0 seed: "lisandra
# M"
# lisandra
# Miandri
# Miardon
# Miardy
# Miaty
# Miarie
# Miarido
# Miari
# Mijsan
# Mikkon
# Kimfry
# Kimmer
# Kimm
# Zemmali
# Zemmpin
# Ae
# ----- Generating with diversity 1.2 seed: "lisandra
# M"
# lisandra
# Mias
# Meyberkin
# Mebroy
# Mefritz
# Mffskey
# Mfti
# Coteuj
# Coettia
# Maffvag
# Maffyer
# Maffo
# Magist
# Maginger
# Maghe
#
#
# Epoch 6/10
#  - 13s - loss: 0.5884
#
# ----- Generating with diversity 0.2 seed: "rydman
# Fry"
# rydman
# Fryen
# Trima
# Trilda
# Trinan
# Triner
# Trin
# Tranis
# Transhius
# Tartanna
# Traunna
# Trandra
# Trandi
# Trardi
# Trardi
# Tr
# ----- Generating with diversity 0.5 seed: "rydman
# Fry"
# rydman
# Fryen
# Trima
# Trimbert
# Triman
# Trima
# Trildi
# Trin
# Trianis
# TracTsra
# Tras
# Tratann
# Tranz
# Trassa
# Tratas
# Trauda
#
# ----- Generating with diversity 1.0 seed: "rydman
# Fry"
# rydman
# Fryen
# Trima
# Trilde
# Trin
# Cjoanahe
# Flbed
# Flahmen
# Flanis
# Fladnes
# Flaldie
# Flachurty
# Flarton
# Flarylle
# FlaFFi
# ----- Generating with diversity 1.2 seed: "rydman
# Fry"
# rydman
# Fryen
# Trima
# Trilda
# Trin
# Cjoranfe
# Rahritt
# Rahishasha
# Mhishba
# Mhithela
# Mhtiahn
# Mhiurbell
# Mhurbetgl
# Miurme
#
#
# Epoch 7/10
#  - 14s - loss: 0.5872
#
# ----- Generating with diversity 0.2 seed: "Barb
# Barba"
# Barb
# Barbanna
# Babban
# Babber
# Babran
# Babbey
# Babersh
# Babeh
# Babeur
# Baber
# Bablee
# Bab
# Balach
# Balaji
# Ballyn
# Balster
# B
# ----- Generating with diversity 0.5 seed: "Barb
# Barba"
# Barb
# Barban
# Barban
# Barbana
# Brabra
# Brabran
# Babbey
# Babersh
# Babette
# Babiene
# Babinger
# Bableim
# Babeina
# Babern
# Baber
# ----- Generating with diversity 1.0 seed: "Barb
# Barba"
# Barb
# Barbas
# Barbure
# Barbord
# Barbore
# Barbord
# Barbord
# Barbore
# Barbore
# Barbor
# Barburk
# Barbyn
# Barcilie
# Bartling
# Ba
# ----- Generating with diversity 1.2 seed: "Barb
# Barba"
# Barb
# Barband
# Barbone
# Barbort
# Barby
# Barbeor
# Barborfon
# Basg
# Basgew
# Bapand
# Baap
# Bara
# Laranes
# Larasty
# Lardia
# Lardi
#
#
# Epoch 8/10
#  - 15s - loss: 0.5854
#
# ----- Generating with diversity 0.2 seed: "ilma
# Vin
# V"
# ilma
# Vin
# ViVan
# VakV
# Valianna
# Valianna
# Valianna
# Valianna
# Valianna
# Valianna
# Valiann
# Valisan
# Vallan
# Valsell
# Valse
# ----- Generating with diversity 0.5 seed: "ilma
# Vin
# V"
# ilma
# Vin
# Vithna
# Vitknna
# Vitmas
# Viposasian
# Gjass
# MacMiatla
# MacFellem
# McCley
# McCollondron
# Floren
# Floron
# Forlie
# F
# ----- Generating with diversity 1.0 seed: "ilma
# Vin
# V"
# ilma
# Vin
# Vitgs
# Varteh
# Varwen
# Varyen
# Varyahts
# Varuntta
# Varthe
# Vartas
# Varte
# Vartera
# Varthard
# Hartmen
# Haromora
# Ha
# ----- Generating with diversity 1.2 seed: "ilma
# Vin
# V"
# ilma
# Vin
# Vitania
# Vitanine
# Vataria
# Vatenie
# Vateri
# Vathie
# Vatzlavor
# A
# Atuer
# Atudrotta
# Andurtes
# Andy
# Andodde
# Andr
#
#
# Epoch 9/10
#  - 12s - loss: 0.5846
#
# ----- Generating with diversity 0.2 seed: "te
# Audi
# Au"
# te
# Audi
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
#
# ----- Generating with diversity 0.5 seed: "te
# Audi
# Au"
# te
# Audi
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audie
# Audely
# Audellurd
# Eudlor
# Edd
# Fagda
# Fages
# Fa
# ----- Generating with diversity 1.0 seed: "te
# Audi
# Au"
# te
# Audi
# Audie
# Auutie
# Auvureck
# Avbice
# Avcher
# Avcec
# Av
# Ahabbece
# Abbey
# Aberta
# Aburit
# Abus
# Abyn
# Abrak
# Abreshom
# Asb
# ----- Generating with diversity 1.2 seed: "te
# Audi
# Au"
# te
# Audi
# Audleul
# Audlery
# Audull
# Audritta
# Anitks
# Anny
# Anoreine
# Ariene
# Arina
# Arisonck
# Assyndy
# Assmann
# Asssman
# Ass
#
#
# Epoch 10/10
#  - 13s - loss: 0.5808
#
# ----- Generating with diversity 0.2 seed: "nald
# Regin"
# nald
# Regingord
# Reiney
# Rein
# Reich
# Reicis
# Reichis
# Reicis
# Reichond
# Rechck
# Reddina
# Redding
# Reddin
# Redyla
# Redell
# Re
# ----- Generating with diversity 0.5 seed: "nald
# Regin"
# nald
# Regingord
# Reinere
# Reiiber
# Reiwan
# Reizan
# Reks
# Rekie
# Rekier
# Reylond
# Reyly
# Reyla
# Rey
# Rey
# Reyd
# Reyda
# Reyder
# R
# ----- Generating with diversity 1.0 seed: "nald
# Regin"
# nald
# Regina
# Reggin
# Rehgine
# Rehi
# Rveid
# Reviane
# Rebbund
# Rebbort
# Rebe
# Rebberg
# Rebeok
# Rebenbel
# Recho
# Rechebbe
# Recm
# ----- Generating with diversity 1.2 seed: "nald
# Regin"
# nald
# Regin
# Regnierd
# Reibellia
# Reiberti
# Reibergh
# Reez
# Rebe
# Rebe
# Rebah
# Rebajeo
# Rebbaly
# Reboze
# Rebbune
# Rebbert
# Re

# %%
# Out:
# 'am\nCramer\n'
